# %%
file = open('data.csv','x')  #create a new csv data file
file.close()

# %%
import pandas as pd   #access the csv file using pandas package
df = pd.read_csv('data.csv')    #df = DataFrame
df
# Out:
#    SN     Name  Age    Address       Phone
# 0   1      Ram   23  Kathmandu   934323432
# 1   2    Shyam   33      Patan   789784874
# 2   3     Hari   44  Bhaktapur   678647678
# 3   4   Sunita   34  Kathmandu  2343244324
# 4   5     Gita   22    Bhojpur   234234234
# 5   6     Nita   25    Pokhara   564654456
# 6   7  Pratima   45  Kathmandu   234234234

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5)
df
# Out:
#    SN    Name  Age    Address       Phone
# 0   1     Ram   23  Kathmandu   934323432
# 1   2   Shyam   33      Patan   789784874
# 2   3    Hari   44  Bhaktapur   678647678
# 3   4  Sunita   34  Kathmandu  2343244324
# 4   5    Gita   22    Bhojpur   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5,index_col = 'SN')  #Making 'SN' the index column
df
# Out:
#       Name  Age    Address       Phone
# SN
# 1      Ram   23  Kathmandu   934323432
# 2    Shyam   33      Patan   789784874
# 3     Hari   44  Bhaktapur   678647678
# 4   Sunita   34  Kathmandu  2343244324
# 5     Gita   22    Bhojpur   234234234

# %%
df['Name']
# Out:
# SN
# 1       Ram
# 2     Shyam
# 3      Hari
# 4    Sunita
# 5      Gita
# Name: Name, dtype: object

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5,index_col = 'SN')
df.head()
# Out:
#       Name  Age    Address       Phone
# SN
# 1      Ram   23  Kathmandu   934323432
# 2    Shyam   33      Patan   789784874
# 3     Hari   44  Bhaktapur   678647678
# 4   Sunita   34  Kathmandu  2343244324
# 5     Gita   22    Bhojpur   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5,index_col = 'SN')
df.head(4)
# Out:
#       Name  Age    Address       Phone
# SN
# 1      Ram   23  Kathmandu   934323432
# 2    Shyam   33      Patan   789784874
# 3     Hari   44  Bhaktapur   678647678
# 4   Sunita   34  Kathmandu  2343244324

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5,index_col = 'SN')
df.tail(2)
# Out:
#       Name  Age    Address       Phone
# SN
# 4   Sunita   34  Kathmandu  2343244324
# 5     Gita   22    Bhojpur   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows = 5,index_col = 'SN')
df.tail()
# Out:
#       Name  Age    Address       Phone
# SN
# 1      Ram   23  Kathmandu   934323432
# 2    Shyam   33      Patan   789784874
# 3     Hari   44  Bhaktapur   678647678
# 4   Sunita   34  Kathmandu  2343244324
# 5     Gita   22    Bhojpur   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')
df
# Out:
#        Name  Age    Address       Phone
# SN
# 1       Ram   23  Kathmandu   934323432
# 2     Shyam   33      Patan   789784874
# 3      Hari   44  Bhaktapur   678647678
# 4    Sunita   34  Kathmandu  2343244324
# 5      Gita   22    Bhojpur   234234234
# 6      Nita   25    Pokhara   564654456
# 7   Pratima   45  Kathmandu   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN',usecols = ['SN','Name','Phone'])
df
# Out:
#        Name       Phone
# SN
# 1       Ram   934323432
# 2     Shyam   789784874
# 3      Hari   678647678
# 4    Sunita  2343244324
# 5      Gita   234234234
# 6      Nita   564654456
# 7   Pratima   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   
df
# Out:
#        Name  Age    Address       Phone
# SN
# 1       Ram   23  Kathmandu   934323432
# 2     Shyam   33      Patan   789784874
# 3      Hari   44  Bhaktapur   678647678
# 4    Sunita   34  Kathmandu  2343244324
# 5      Gita   22    Bhojpur   234234234
# 6      Nita   25    Pokhara   564654456
# 7   Pratima   45  Kathmandu   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   #filtering by rows
df['Address'] == 'Kathmandu'
# Out:
# SN
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# Name: Address, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   #filtering by rows
df[df['Address'] == 'Kathmandu']
# Out:
#        Name  Age    Address       Phone
# SN
# 1       Ram   23  Kathmandu   934323432
# 4    Sunita   34  Kathmandu  2343244324
# 7   Pratima   45  Kathmandu   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   
data = df[df['Address'] == 'Kathmandu']
data.to_csv('new_data.csv')     #new data file opened and written

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   
data = df[df['Age'] > 30]   #filtering by age
data
# Out:
#        Name  Age    Address       Phone
# SN
# 2     Shyam   33      Patan   789784874
# 3      Hari   44  Bhaktapur   678647678
# 4    Sunita   34  Kathmandu  2343244324
# 7   Pratima   45  Kathmandu   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   
df.iloc[1:5]       #selecting by index
# Out:
#       Name  Age    Address       Phone
# SN
# 2    Shyam   33      Patan   789784874
# 3     Hari   44  Bhaktapur   678647678
# 4   Sunita   34  Kathmandu  2343244324
# 5     Gita   22    Bhojpur   234234234

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   
df.iloc[1:4,0:3]       #selecting by index
# Out:
#       Name  Age    Address
# SN
# 2    Shyam   33      Patan
# 3     Hari   44  Bhaktapur
# 4   Sunita   34  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'SN')   
df.loc[2:6]
# Out:
#       Name  Age    Address       Phone
# SN
# 2    Shyam   33      Patan   789784874
# 3     Hari   44  Bhaktapur   678647678
# 4   Sunita   34  Kathmandu  2343244324
# 5     Gita   22    Bhojpur   234234234
# 6     Nita   25    Pokhara   564654456

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')   
df["Ram":"Gita"]
# Out:
#         SN  Age    Address       Phone
# Name
# Ram      1   23  Kathmandu   934323432
# Shyam    2   33      Patan   789784874
# Hari     3   44  Bhaktapur   678647678
# Sunita   4   34  Kathmandu  2343244324
# Gita     5   22    Bhojpur   234234234

# %%
#Converting dictionary into DataFrame
import pandas as pd
data = {'Ram': [987877777, 342342], 'Shyam': [9832343243, 989887974]}
df = pd.DataFrame(data)
#df.to_csv('phone_no.csv')     #create and write to new csv file
df
# Out:
#          Ram       Shyam
# 0  987877777  9832343243
# 1     342342   989887974
